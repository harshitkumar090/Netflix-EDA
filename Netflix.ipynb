# %%
#import all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta

# %%
#show data
df=pd.read_csv('netflix1.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.size
# Out:
# 105684

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
new_fill=df.fillna("Earth")

# %%
df=df.fillna({
    "director":"Komal Singhania",
    "cast":"Salman",
    "country":"Bharat"
    
})
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water  Komal Singhania
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Komal Singhania
# 4      s5  TV Show           Kota Factory  Komal Singhania
#
#                                                 cast        country  \
# 0                                             Salman  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         Bharat
# 3                                             Salman         Bharat
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df=df.fillna({
    "director":"Komal Singhania"[2],
    "cast":"Salman",
    "country":"Bharat"
    
})
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water                m
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans                m
# 4      s5  TV Show           Kota Factory                m
#
#                                                 cast        country  \
# 0                                             Salman  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         Bharat
# 3                                             Salman         Bharat
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df.loc[df[("show_id")]=="s2",["title","rating"]]=["Ram RAm","5G"]    
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show                Ram RAm                m
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans                m
# 4      s5  TV Show           Kota Factory                m
#
#                                                 cast        country  \
# 0                                             Salman  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         Bharat
# 3                                             Salman         Bharat
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021     5G  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df.keys()
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.values
# Out:
# array([['s1', 'Movie', 'Dick Johnson Is Dead', ..., '90 min',
#         'Documentaries',
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'],
#        ['s2', 'TV Show', 'Blood & Water', ..., '2 Seasons',
#         'International TV Shows, TV Dramas, TV Mysteries',
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.'],
#        ['s3', 'TV Show', 'Ganglands', ..., '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure',
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.'],
#        ...,
#        ['s8805', 'Movie', 'Zombieland', ..., '88 min',
#         'Comedies, Horror Movies',
# ...

# %%
netflix=df.drop(index=2)     
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
re=df[df["release_year"]==2020]
re
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17       s18  TV Show                                    Falsa identidad
# 32       s33  TV Show                                      Sex Education
# 34       s35  TV Show                            Tayo and Little Wizards
# ...      ...      ...                                                ...
# 5972   s5973    Movie                                   #cats_the_mewvie
# 7594   s7595    Movie                 Norm of the North: Family Vacation
# 8099   s8100    Movie                                        Straight Up
# 8125   s8126  TV Show                                        Super Wings
# 8132   s8133  TV Show          Surviving R. Kelly Part II: The Reckoning
#
#                                            director  \
# ...

# %%
df.query("release_year==2021")
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df.query("duration == '90 min'") #use single qoutes using access string dtype
# Out:
#      show_id   type                            title             director  \
# 0         s1  Movie             Dick Johnson Is Dead      Kirsten Johnson
# 94       s95  Movie                        Show Dogs         Raja Gosnell
# 107     s108  Movie                 A Champion Heart         David de Vos
# 229     s230  Movie                     The Old Ways  Christopher Alender
# 283     s284  Movie             Misha and the Wolves        Sam Hobkinson
# ...      ...    ...                              ...                  ...
# 8651   s8652  Movie                            Tyson         James Toback
# 8655   s8656  Movie             Unaccompanied Minors            Paul Feig
# 8670   s8671  Movie                    Vantage Point          Pete Travis
# 8735   s8736  Movie  Who's That Knocking at My Door?      Martin Scorsese
# 8776   s8777  Movie                       Yellowbird    Christian De Vita
#
#                                                    cast  \
# ...

# %%
df[df["duration"]=="90 min"]
# Out:
#      show_id   type                            title             director  \
# 0         s1  Movie             Dick Johnson Is Dead      Kirsten Johnson
# 94       s95  Movie                        Show Dogs         Raja Gosnell
# 107     s108  Movie                 A Champion Heart         David de Vos
# 229     s230  Movie                     The Old Ways  Christopher Alender
# 283     s284  Movie             Misha and the Wolves        Sam Hobkinson
# ...      ...    ...                              ...                  ...
# 8651   s8652  Movie                            Tyson         James Toback
# 8655   s8656  Movie             Unaccompanied Minors            Paul Feig
# 8670   s8671  Movie                    Vantage Point          Pete Travis
# 8735   s8736  Movie  Who's That Knocking at My Door?      Martin Scorsese
# 8776   s8777  Movie                       Yellowbird    Christian De Vita
#
#                                                    cast  \
# ...

# %%
df.query("director=='Kirsten Johnson'")
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#   date_added  release_year rating duration      listed_in  \
# 0  25-Sep-21          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
rename=df.rename(columns={'type':'genre'})
rename.head()
# Out:
#   show_id    genre                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df.sort_values(by="release_year")
# Out:
#      show_id     type                               title  \
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 8763   s8764    Movie     WWII: Report from the Aleutians
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# ...      ...      ...                                 ...
# 1310   s1311  TV Show                            The Crew
# 30       s31    Movie                     Ankahi Kahaniya
# 64       s65    Movie                          Nightbooks
# 1317   s1318  TV Show                        Nadiya Bakes
# 12       s13    Movie                        Je Suis Karl
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %%
df.sort_values(by=["director","duration"])
# Out:
#      show_id   type                                     title  \
# 6078   s6079  Movie                                 Abhinetri
# 3537   s3538  Movie                                  Watchman
# 2389   s2390  Movie                                Asura Guru
# 5549   s5550  Movie                                 Salaakhen
# 4681   s4682  Movie                                    Spyder
# ...      ...    ...                                       ...
# 5611   s5612  Movie                          Grillo vs Grillo
# 641     s642  Movie                          Sisters on Track
# 1431   s1432  Movie                               Stuck Apart
# 2608   s2609  Movie  Murder to Mercy: The Cyntoia Brown Story
# 6650   s6651  Movie                           Driven to Dance
#
#              director                                               cast  \
# 6078      A. L. Vijay  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...
# ...

# %%
df.sort_values(by=["director","duration"],ascending=[True,False])
#We can also sort one column ascending order and descending with other column
# Out:
#      show_id     type               title         director  \
# 3537   s3538    Movie            Watchman      A. L. Vijay
# 6078   s6079    Movie           Abhinetri      A. L. Vijay
# 2389   s2390    Movie          Asura Guru     A. Raajdheep
# 5549   s5550    Movie           Salaakhen        A. Salaam
# 4049   s4050    Movie              Sarkar  A.R. Murugadoss
# ...      ...      ...                 ...              ...
# 8775   s8776  TV Show     Yeh Meri Family              NaN
# 8780   s8781  TV Show        Yo-Kai Watch              NaN
# 8783   s8784  TV Show                Yoko              NaN
# 8785   s8786  TV Show                 YOM              NaN
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
#
#                                                    cast        country  \
# 3537  G.V. Prakash Kumar, Samyuktha Hegde, Suman, Ra...          India
# 6078  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...          India
# ...

# %%
drop=df.drop(columns=['description'])
drop.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
df.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
df["release_year"].value_counts() #It count values in a column. It just work with series!
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
df.mean(numeric_only=True) #Compute mean of each column if it's numeric
# Out:
# release_year    2014.180198
# dtype: float64

# %%
df.groupby("type").size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
df[df["director"]=="Kirsten Johnson"]
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#   date_added  release_year rating duration      listed_in  \
# 0  25-Sep-21          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %%
new_fill.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water            Earth
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans            Earth
# 4      s5  TV Show           Kota Factory            Earth
#
#                                                 cast        country  \
# 0                                              Earth  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...          Earth
# 3                                              Earth          Earth
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# ...

# %%
#remove all null values
new_df=df.dropna()
new_df.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  24-Sep-21
# 8                                      United Kingdom  24-Sep-21
# ...

# %%
#describe Dataset.
new_df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
#Null Values
new_df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
#show all columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#show all unique record
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8804
# director        4529
# cast            7693
# country          749
# date_added      1767
# release_year      74
# rating            18
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.iloc[0]
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                       Salman
# country                                             United States
# date_added                                              25-Sep-21
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: 0, dtype: object

# %%
#show only country United State
df[df['country']=='United States']
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People                m
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                Salman  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df.agg({'release_year':'count'})  #max min avg
# Out:
# release_year    8807
# dtype: int64

# %%
#measure the Shape
print('Number of Rows:', new_df.shape[0])
print('Number of Columns:', new_df.shape[1])
df.info()
# Out:
# Number of Rows: 5332
# Number of Columns: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#remove all the duplicates
print('Drop Duplicate:', new_df.duplicated().sum())
new_df=new_df.drop_duplicates()
print('After Removing Duplicate:', new_df.duplicated().sum())
# Out:
# Drop Duplicate: 0
# After Removing Duplicate: 0

# %%
#shape the database 
new_df.shape
# Out:
# (5332, 12)

# %%
#Count Movies and TV shows
types=new_df['type'].value_counts()
plt.pie(types, labels=types.index, autopct='%1.1f%%', shadow=True)         
plt.title('Movies and Tv Shows', color='red', size=15)
plt.show()

# %%
#Top 10 Populart Generes.
generes=new_df['listed_in'].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=generes.values, y=generes.index, palette='viridis', orient='h')  
plt.title('Top 10 popular Generes', color='r', size=20)
plt.xlabel('Count', color='green', size=15)
plt.ylabel('Generes', color='green', size=15)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15892\3426579226.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=generes.values, y=generes.index, palette='viridis', orient='h')

# %%
#Top 10 Country by releasing movies and Tv shows
country=new_df['country'].value_counts().head(10)
sns.barplot(x=country.values, y=country.index, palette='viridis')
plt.title('Top 10 country by relesing Movies and Series', size=20, color='blue')
plt.xlabel('Count', size=15, color='red')
plt.ylabel('Country Name', size=15, color='red')
plt.show()
# Out:
# C:\Users\SHUBHAM KUMAR\AppData\Local\Temp\ipykernel_32144\256501540.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country.values, y=country.index, palette='viridis')

# %%
#count total movies and Tv shows
total_movie=df['release_year'].count()                                                      
print(total_movie)
# Out:
# 8807

# %%
#Max movies in year
sns.kdeplot(data=new_df['release_year'], fill=True)
plt.show()

# %%
#Top 3 rateing
rating=new_df['rating'].value_counts().head(3)
plt.pie(rating, labels=rating.index, autopct='%1.1f%%', shadow=True)
plt.title('Top')
plt.show()

# %%
title=new_df['title'].value_counts().head(10)
duration=df['duration'].value_counts().head(10)
sns.barplot(y=title.index, x=duration.values, palette='viridis', orient='h')
plt.title('Top 10 longest Movies and Series', color='blue', size=20)
plt.xlabel('Duration', color='red', size=15)
plt.ylabel('Title', color='red', size=15)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15892\1727672927.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=title.index, x=duration.values, palette='viridis', orient='h')

# %%
sns.pairplot(df, hue='type')                                             
plt.legend()
plt.show()
# Out:
# C:\Users\SHUBHAM KUMAR\AppData\Local\Temp\ipykernel_25684\2720130489.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
